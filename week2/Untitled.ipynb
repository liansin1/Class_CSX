# %%
import requests
import json
import csv 
import time, datetime
#from bs4 import BeautifulSoup
#import lxml

# %%
res = requests.get("https://histock.tw/stock/tcharti.aspx?no=0000&m=all")
soup = BeautifulSoup(res.text, 'lxml')
#print(res.text)

# %%
res
# Out:
# <Response [200]>

# %%
soup
# Out:
# <!DOCTYPE html>
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head id="Head1"><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><title>
# 	台股大盤(0000) - 動態長期歷史K線圖 - HiStock 嗨投資
# ...

# %%
import requests
import json
import csv 
import time, datetime

# %%
dt = datetime.datetime.now()
dt.year
dt.month
# Out:
# 3

# %%
id_list = ['1203']
now = datetime.datetime.now()
year_list = range(2016,now.year+1) #since 2016 to this year
month_list = range(1,13) # 12 months

# %%
def get_websmg(year,month,stock_id):
    date = str(year) + "{0:0=2d}".format(month) + '01'
    sid = str(stock_id)
    url_twse = 'http://www.tse.com.tw/exchangeReport/STOCK_DAY?response=json&date='date&stockNo=1234'

# %%
for stock_id in id_list:
    for year in year_list:
        for month in month_list:
            if (dt.year == year & month > dt.month) :break
            sid = str(stock_id)
            yy = str(year)
            mm = month
            directory = 'D:/stock'+'/'+sid+'/'+yy+'/'
            filename = str(yy)+str("%02d"%mm)+'.csv' 
            smt = get_websmg(year,month,stock_id)
            makedirs(year,month,stock_id)
            write_csv(stock_id,directory,filename,smt)
            time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-b75aa68bc09f> in <module>()
#       8             directory = 'D:/stock'+'/'+sid+'/'+yy+'/'
#       9             filename = str(yy)+str("%02d"%mm)+'.csv'
# ---> 10             smt = get_websmg(year,month,stock_id)
#      11             makedirs(year,month,stock_id)
#      12             write_csv(stock_id,directory,filename,smt)
#
# NameError: name 'get_websmg' is not defined

# %%
url = 'http://www.tse.com.tw/exchangeReport/STOCK_DAY?date=20170605&stockNo=1234'

# %%
res = requests.get(url)

# %%
res
# Out:
# <Response [200]>

# %%
res.text
# Out:
# '{"stat":"OK","date":"20170605","title":"106年06月 1234 黑松             各日成交資訊","fields":["日期","成交股數","成交金額","開盤價","最高價","最低價","收盤價","漲跌價差","成交筆數"],"data":[["106/06/01","58,158","1,943,342","33.55","33.55","33.35","33.55","+0.05","52"],["106/06/02","54,833","1,843,099","33.55","33.80","33.50","33.50","-0.05","51"],["106/06/03","27,106","908,600","33.60","33.65","33.35","33.60","+0.10","28"],["106/06/05","95,560","3,208,052","33.60","33.75","33.50","33.50","-0.10","79"],["106/06/06","40,922","1,371,242","33.70","33.70","33.50","33.50"," 0.00","43"],["106/06/07","33,751","1,130,520","33.55","33.55","33.45","33.50"," 0.00","29"],["106/06/08","55,243","1,852,313","33.80","33.80","33.45","33.50"," 0.00","43"],["106/06/09","124,640","4,162,505","33.50","33.50","33.35","33.45","-0.05","75"],["106/06/12","63,356","2,115,471","33.65","33.65","33.30","33.45"," 0.00","56"],["106/06/13","83,266","2,789,742","33.75","33.75","33.40","33.45"," 0.00","69"],["106/06/14","67,921","2,267,363","33.35","33.
# ...

# %%
decoder = json.JSONDecoder()
stock = decoder.decode(res.text)

# %%
stock["notes"]
# Out:
# ['符號說明:+/-/X表示漲/跌/不比價',
#  '當日統計資訊含一般、零股、盤後定價、鉅額交易，不含拍賣、標購。',
#  'ETF證券代號第六碼為K、M、S、C者，表示該ETF以外幣交易。']

# %%
stock['data'][0][0]
# Out:
# '106/06/01'
